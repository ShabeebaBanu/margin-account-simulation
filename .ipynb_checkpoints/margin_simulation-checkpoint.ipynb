# %% [markdown]
# # Margin Account Simulation in Derivatives Market
#
# ## 1. Introduction
#
# ## 2. Input Parameters & Assumptions
#
# ## 3. Settlement Price Generation
#
# ## 4. Margin Account Logic
# - Buyer Account
# - Seller Account
#
# ## 5. Mark-to-Market & Margin Calls
#
# ## 6. Results & Output Tables
#
# ## 7. Observations & Conclusion
